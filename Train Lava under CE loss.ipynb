# %%
from transformers import AutoModelForMaskedLM, TrainingArguments, Trainer
import torch

from lava import LavaModel
model = LavaModel.from_lava_pretrained('roberta-base', 'facebook/bart-base')

from utils.datasets_config import get_dataset

dset = get_dataset('gigaword', 'facebook/bart-base')
print(dset)
# Out:
# Some weights of BartForQuestionAnswering were not initialized from the model checkpoint at facebook/bart-base and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You passed along `num_labels=3` with an incompatible id to label map: {0: 'LABEL_0', 1: 'LABEL_1'}. The number of labels wil be overwritten to 2.
# Found cached dataset gigaword (/home/ruihan/.cache/huggingface/datasets/gigaword/default/1.2.0/ea83a8b819190acac5f2dae011fad51dccf269a0604ec5dd24795b64efb424b6)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Loading cached processed dataset at /home/ruihan/.cache/huggingface/datasets/gigaword/default/1.2.0/ea83a8b819190acac5f2dae011fad51dccf269a0604ec5dd24795b64efb424b6/cache-6816d5b30b6eeb9a.arrow
# Loading cached processed dataset at /home/ruihan/.cache/huggingface/datasets/gigaword/default/1.2.0/ea83a8b819190acac5f2dae011fad51dccf269a0604ec5dd24795b64efb424b6/cache-6aeaeef7bff602c5.arrow
# Loading cached processed dataset at /home/ruihan/.cache/huggingface/datasets/gigaword/default/1.2.0/ea83a8b819190acac5f2dae011fad51dccf269a0604ec5dd24795b64efb424b6/cache-29041409e3286f61.arrow
# Number of gigaword training examples: 3803957
# Number of gigaword validation examples: 189651
# Number of gigaword testing examples: 1951
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels', 'input_texts', 'label_texts'],
#         num_rows: 3803957
#     })
#     validation: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels', 'input_texts', 'label_texts'],
#         num_rows: 189651
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels', 'input_texts', 'label_texts'],
#         num_rows: 1951
#     })
# })

# %%
training_args = TrainingArguments(
    # evaluation_strategy = "steps",
    output_dir= 'lava-ce',
    overwrite_output_dir=True,
    num_train_epochs=1,
    max_steps = 700_000,
    per_device_train_batch_size=32,
    save_steps=5_000,
    save_total_limit=3,
    prediction_loss_only=True,
    dataloader_num_workers=4,
    # learning_rate=3e-4,
    # logging_steps = 5,
    # eval_steps = 5,
    # metric_for_best_model = 'f1',
    # load_best_model_at_end=True,
)

# %%
def collate(batch):
    batch = ({k: torch.nn.utils.rnn.pad_sequence([dic[k] for dic in batch], batch_first=True, padding_value=1) for k in batch[0]})
    batch['input_ids'][batch['input_ids'] == 2] = 0
    batch['attention_mask'] = (batch['input_ids'] != 1).long()
    batch['labels'][batch['labels']==1] = -100
    return batch

# %%
trainer = Trainer(
    model = model,
    args = training_args,
    train_dataset = dset['train'].shuffle(1234),
    eval_dataset = dset['validation'].shard(300, 1),
    data_collator = collate,
    # compute_metrics = lambda x: print(x),
    # callbacks = [EarlyStoppingCallback(early_stopping_patience=7)],
)
# Out:
# Loading cached shuffled indices for dataset at /home/ruihan/.cache/huggingface/datasets/gigaword/default/1.2.0/ea83a8b819190acac5f2dae011fad51dccf269a0604ec5dd24795b64efb424b6/cache-aac49639e82619d5.arrow
# max_steps is given, it will override any value given in num_train_epochs

# %%
trainer.train(resume_from_checkpoint = True)
# Out:
# Loading model from lava-ce/checkpoint-350000.
# The following columns in the training set don't have a corresponding argument in `LavaModel.forward` and have been ignored: label_texts, input_texts. If label_texts, input_texts are not expected by `LavaModel.forward`,  you can safely ignore this message.
# /home/ruihan/anaconda3/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 3803957
#   Num Epochs = 6
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 700000
#   Continuing training from checkpoint, will skip to saved global_step
#   Continuing training from epoch 2
#   Continuing training from global step 350000
#   Will skip the first 2 epochs then the first 112252 batches in the first epoch. If this takes a lot of time, you can add the `--ignore_data_skip` flag to your launch command, but you will resume the training on data already seen by your model.
#   0%|          | 0/112252 [00:00<?, ?it/s]
#     <div>
#
#       <progress value='408667' max='700000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [408667/700000 3:47:50 < 18:51:28, 4.29 it/s, Epoch 3.44/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>350500</td>
#       <td>2.333100</td>
#     </tr>
#     <tr>
#       <td>351000</td>
#       <td>2.334600</td>
#     </tr>
#     <tr>
#       <td>351500</td>
#       <td>2.333600</td>
#     </tr>
#     <tr>
#       <td>352000</td>
#       <td>2.347100</td>
#     </tr>
#     <tr>
#       <td>352500</td>
#       <td>2.312500</td>
#     </tr>
#     <tr>
#       <td>353000</td>
#       <td>2.316800</td>
#     </tr>
#     <tr>
#       <td>353500</td>
#       <td>2.336800</td>
#     </tr>
#     <tr>
#       <td>354000</td>
#       <td>2.319000</td>
#     </tr>
#     <tr>
#       <td>354500</td>
#       <td>2.314200</td>
#     </tr>
#     <tr>
#       <td>355000</td>
#       <td>2.315300</td>
#     </tr>
#     <tr>
#       <td>355500</td>
#       <td>2.345900</td>
#     </tr>
#     <tr>
#       <td>356000</td>
#       <td>2.332400</td>
#     </tr>
#     <tr>
#       <td>356500</td>
#       <td>2.312600</td>
#     </tr>
#     <tr>
#       <td>357000</td>
#       <td>2.303800</td>
#     </tr>
#     <tr>
#       <td>357500</td>
#       <td>2.285000</td>
#     </tr>
#     <tr>
#       <td>358000</td>
#       <td>2.293500</td>
#     </tr>
#     <tr>
#       <td>358500</td>
#       <td>2.300900</td>
#     </tr>
#     <tr>
#       <td>359000</td>
#       <td>2.305400</td>
#     </tr>
#     <tr>
#       <td>359500</td>
#       <td>2.300400</td>
#     </tr>
#     <tr>
#       <td>360000</td>
#       <td>2.282300</td>
#     </tr>
#     <tr>
#       <td>360500</td>
#       <td>2.282000</td>
#     </tr>
#     <tr>
#       <td>361000</td>
#       <td>2.277700</td>
#     </tr>
#     <tr>
#       <td>361500</td>
#       <td>2.303100</td>
#     </tr>
#     <tr>
#       <td>362000</td>
#       <td>2.301700</td>
#     </tr>
#     <tr>
#       <td>362500</td>
#       <td>2.279400</td>
#     </tr>
#     <tr>
#       <td>363000</td>
#       <td>2.297000</td>
#     </tr>
#     <tr>
#       <td>363500</td>
#       <td>2.303700</td>
#     </tr>
#     <tr>
#       <td>364000</td>
#       <td>2.282300</td>
#     </tr>
#     <tr>
#       <td>364500</td>
#       <td>2.304500</td>
#     </tr>
#     <tr>
#       <td>365000</td>
#       <td>2.311000</td>
#     </tr>
#     <tr>
#       <td>365500</td>
#       <td>2.278700</td>
#     </tr>
#     <tr>
#       <td>366000</td>
#       <td>2.301500</td>
#     </tr>
#     <tr>
#       <td>366500</td>
#       <td>2.294700</td>
#     </tr>
#     <tr>
#       <td>367000</td>
#       <td>2.290700</td>
#     </tr>
#     <tr>
#       <td>367500</td>
#       <td>2.290400</td>
#     </tr>
#     <tr>
#       <td>368000</td>
#       <td>2.269900</td>
#     </tr>
#     <tr>
#       <td>368500</td>
#       <td>2.269900</td>
#     </tr>
#     <tr>
#       <td>369000</td>
#       <td>2.264600</td>
#     </tr>
#     <tr>
#       <td>369500</td>
#       <td>2.280600</td>
#     </tr>
#     <tr>
#       <td>370000</td>
#       <td>2.266500</td>
#     </tr>
#     <tr>
#       <td>370500</td>
#       <td>2.292800</td>
#     </tr>
#     <tr>
#       <td>371000</td>
#       <td>2.287800</td>
#     </tr>
#     <tr>
#       <td>371500</td>
#       <td>2.286300</td>
#     </tr>
#     <tr>
#       <td>372000</td>
#       <td>2.301900</td>
#     </tr>
#     <tr>
#       <td>372500</td>
#       <td>2.286200</td>
#     </tr>
#     <tr>
#       <td>373000</td>
#       <td>2.282700</td>
#     </tr>
#     <tr>
#       <td>373500</td>
#       <td>2.284500</td>
#     </tr>
#     <tr>
#       <td>374000</td>
#       <td>2.305000</td>
#     </tr>
#     <tr>
#       <td>374500</td>
#       <td>2.271200</td>
#     </tr>
#     <tr>
#       <td>375000</td>
#       <td>2.293100</td>
#     </tr>
#     <tr>
#       <td>375500</td>
#       <td>2.292000</td>
#     </tr>
#     <tr>
#       <td>376000</td>
#       <td>2.294100</td>
#     </tr>
#     <tr>
#       <td>376500</td>
#       <td>2.293500</td>
#     </tr>
#     <tr>
#       <td>377000</td>
#       <td>2.284000</td>
#     </tr>
#     <tr>
#       <td>377500</td>
#       <td>2.287300</td>
#     </tr>
#     <tr>
#       <td>378000</td>
#       <td>2.285700</td>
#     </tr>
#     <tr>
#       <td>378500</td>
#       <td>2.302200</td>
#     </tr>
#     <tr>
#       <td>379000</td>
#       <td>2.296600</td>
#     </tr>
#     <tr>
#       <td>379500</td>
#       <td>2.296900</td>
#     </tr>
#     <tr>
#       <td>380000</td>
#       <td>2.267300</td>
#     </tr>
#     <tr>
#       <td>380500</td>
#       <td>2.286400</td>
#     </tr>
#     <tr>
#       <td>381000</td>
#       <td>2.283000</td>
#     </tr>
#     <tr>
#       <td>381500</td>
#       <td>2.272600</td>
#     </tr>
#     <tr>
#       <td>382000</td>
#       <td>2.288500</td>
#     </tr>
#     <tr>
#       <td>382500</td>
#       <td>2.296600</td>
#     </tr>
#     <tr>
#       <td>383000</td>
#       <td>2.282500</td>
#     </tr>
#     <tr>
#       <td>383500</td>
#       <td>2.294900</td>
#     </tr>
#     <tr>
#       <td>384000</td>
#       <td>2.296800</td>
#     </tr>
#     <tr>
#       <td>384500</td>
#       <td>2.284700</td>
#     </tr>
#     <tr>
#       <td>385000</td>
#       <td>2.280000</td>
#     </tr>
#     <tr>
#       <td>385500</td>
#       <td>2.284100</td>
#     </tr>
#     <tr>
#       <td>386000</td>
#       <td>2.286100</td>
#     </tr>
#     <tr>
#       <td>386500</td>
#       <td>2.299100</td>
#     </tr>
#     <tr>
#       <td>387000</td>
#       <td>2.301900</td>
#     </tr>
#     <tr>
#       <td>387500</td>
#       <td>2.300900</td>
#     </tr>
#     <tr>
#       <td>388000</td>
#       <td>2.298500</td>
#     </tr>
#     <tr>
#       <td>388500</td>
#       <td>2.299400</td>
#     </tr>
#     <tr>
#       <td>389000</td>
#       <td>2.282300</td>
#     </tr>
#     <tr>
#       <td>389500</td>
#       <td>2.286600</td>
#     </tr>
#     <tr>
#       <td>390000</td>
#       <td>2.304700</td>
#     </tr>
#     <tr>
#       <td>390500</td>
#       <td>2.277200</td>
#     </tr>
#     <tr>
#       <td>391000</td>
#       <td>2.275700</td>
#     </tr>
#     <tr>
#       <td>391500</td>
#       <td>2.389200</td>
#     </tr>
#     <tr>
#       <td>392000</td>
#       <td>2.379400</td>
#     </tr>
#     <tr>
#       <td>392500</td>
#       <td>2.379100</td>
#     </tr>
#     <tr>
#       <td>393000</td>
#       <td>2.394300</td>
#     </tr>
#     <tr>
#       <td>393500</td>
#       <td>2.379200</td>
#     </tr>
#     <tr>
#       <td>394000</td>
#       <td>2.363700</td>
#     </tr>
#     <tr>
#       <td>394500</td>
#       <td>2.384800</td>
#     </tr>
#     <tr>
#       <td>395000</td>
#       <td>2.368000</td>
#     </tr>
#     <tr>
#       <td>395500</td>
#       <td>2.379100</td>
#     </tr>
#     <tr>
#       <td>396000</td>
#       <td>2.396300</td>
#     </tr>
#     <tr>
#       <td>396500</td>
#       <td>2.367700</td>
#     </tr>
#     <tr>
#       <td>397000</td>
#       <td>2.358800</td>
#     </tr>
#     <tr>
#       <td>397500</td>
#       <td>2.375000</td>
#     </tr>
#     <tr>
#       <td>398000</td>
#       <td>2.364900</td>
#     </tr>
#     <tr>
#       <td>398500</td>
#       <td>2.374500</td>
#     </tr>
#     <tr>
#       <td>399000</td>
#       <td>2.377100</td>
#     </tr>
#     <tr>
#       <td>399500</td>
#       <td>2.380800</td>
#     </tr>
#     <tr>
#       <td>400000</td>
#       <td>2.379000</td>
#     </tr>
#     <tr>
#       <td>400500</td>
#       <td>2.372700</td>
#     </tr>
#     <tr>
#       <td>401000</td>
#       <td>2.368700</td>
#     </tr>
#     <tr>
#       <td>401500</td>
#       <td>2.371200</td>
#     </tr>
#     <tr>
#       <td>402000</td>
#       <td>2.378100</td>
#     </tr>
#     <tr>
#       <td>402500</td>
#       <td>2.351500</td>
#     </tr>
#     <tr>
#       <td>403000</td>
#       <td>2.377600</td>
#     </tr>
#     <tr>
#       <td>403500</td>
#       <td>2.380100</td>
#     </tr>
#     <tr>
#       <td>404000</td>
#       <td>2.356900</td>
#     </tr>
#     <tr>
#       <td>404500</td>
#       <td>2.358500</td>
#     </tr>
#     <tr>
#       <td>405000</td>
#       <td>2.372200</td>
#     </tr>
#     <tr>
#       <td>405500</td>
#       <td>2.365900</td>
#     </tr>
#     <tr>
#       <td>406000</td>
#       <td>2.364700</td>
#     </tr>
#     <tr>
#       <td>406500</td>
#       <td>2.375500</td>
#     </tr>
#     <tr>
#       <td>407000</td>
#       <td>2.375000</td>
#     </tr>
#     <tr>
#       <td>407500</td>
#       <td>2.369900</td>
#     </tr>
#     <tr>
#       <td>408000</td>
#       <td>2.366700</td>
#     </tr>
#     <tr>
#       <td>408500</td>
#       <td>2.366100</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to lava-ce/checkpoint-355000
# Configuration saved in lava-ce/checkpoint-355000/config.json
# Model weights saved in lava-ce/checkpoint-355000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-340000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-360000
# Configuration saved in lava-ce/checkpoint-360000/config.json
# Model weights saved in lava-ce/checkpoint-360000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-345000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-365000
# Configuration saved in lava-ce/checkpoint-365000/config.json
# Model weights saved in lava-ce/checkpoint-365000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-350000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-370000
# Configuration saved in lava-ce/checkpoint-370000/config.json
# Model weights saved in lava-ce/checkpoint-370000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-355000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-375000
# Configuration saved in lava-ce/checkpoint-375000/config.json
# Model weights saved in lava-ce/checkpoint-375000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-360000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-380000
# Configuration saved in lava-ce/checkpoint-380000/config.json
# Model weights saved in lava-ce/checkpoint-380000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-365000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-385000
# Configuration saved in lava-ce/checkpoint-385000/config.json
# Model weights saved in lava-ce/checkpoint-385000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-370000] due to args.save_total_limit
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Saving model checkpoint to lava-ce/checkpoint-400000
# Configuration saved in lava-ce/checkpoint-400000/config.json
# Model weights saved in lava-ce/checkpoint-400000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-385000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-405000
# Configuration saved in lava-ce/checkpoint-405000/config.json
# Model weights saved in lava-ce/checkpoint-405000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-390000] due to args.save_total_limit

# %%
trainer.evaluate()
