# %%
from transformers import AutoModelForMaskedLM, TrainingArguments, Trainer
import torch

from lava import LavaModel
model = LavaModel.from_lava_pretrained('roberta-base', 'facebook/bart-base')

from utils.datasets_config import get_dataset

dset = get_dataset('gigaword', 'facebook/bart-base')
print(dset)
# Out:
# Some weights of BartForQuestionAnswering were not initialized from the model checkpoint at facebook/bart-base and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You passed along `num_labels=3` with an incompatible id to label map: {0: 'LABEL_0', 1: 'LABEL_1'}. The number of labels wil be overwritten to 2.
# Found cached dataset gigaword (/home/ruihan/.cache/huggingface/datasets/gigaword/default/1.2.0/ea83a8b819190acac5f2dae011fad51dccf269a0604ec5dd24795b64efb424b6)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Loading cached processed dataset at /home/ruihan/.cache/huggingface/datasets/gigaword/default/1.2.0/ea83a8b819190acac5f2dae011fad51dccf269a0604ec5dd24795b64efb424b6/cache-6816d5b30b6eeb9a.arrow
# Loading cached processed dataset at /home/ruihan/.cache/huggingface/datasets/gigaword/default/1.2.0/ea83a8b819190acac5f2dae011fad51dccf269a0604ec5dd24795b64efb424b6/cache-6aeaeef7bff602c5.arrow
# Loading cached processed dataset at /home/ruihan/.cache/huggingface/datasets/gigaword/default/1.2.0/ea83a8b819190acac5f2dae011fad51dccf269a0604ec5dd24795b64efb424b6/cache-29041409e3286f61.arrow
# Number of gigaword training examples: 3803957
# Number of gigaword validation examples: 189651
# Number of gigaword testing examples: 1951
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels', 'input_texts', 'label_texts'],
#         num_rows: 3803957
#     })
#     validation: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels', 'input_texts', 'label_texts'],
#         num_rows: 189651
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels', 'input_texts', 'label_texts'],
#         num_rows: 1951
#     })
# })

# %%
training_args = TrainingArguments(
    # evaluation_strategy = "steps",
    output_dir= 'lava-ce',
    overwrite_output_dir=True,
    num_train_epochs=1,
    max_steps = 700_000,
    per_device_train_batch_size=32,
    save_steps=5_000,
    save_total_limit=3,
    prediction_loss_only=True,
    dataloader_num_workers=4,
    # learning_rate=3e-4,
    # logging_steps = 5,
    # eval_steps = 5,
    # metric_for_best_model = 'f1',
    # load_best_model_at_end=True,
)

# %%
def collate(batch):
    batch = ({k: torch.nn.utils.rnn.pad_sequence([dic[k] for dic in batch], batch_first=True, padding_value=1) for k in batch[0]})
    batch['input_ids'][batch['input_ids'] == 2] = 0
    batch['attention_mask'] = (batch['input_ids'] != 1).long()
    batch['labels'][batch['labels']==1] = -100
    return batch

# %%
trainer = Trainer(
    model = model,
    args = training_args,
    train_dataset = dset['train'].shuffle(1234),
    eval_dataset = dset['validation'].shard(300, 1),
    data_collator = collate,
    # compute_metrics = lambda x: print(x),
    # callbacks = [EarlyStoppingCallback(early_stopping_patience=7)],
)
# Out:
# Loading cached shuffled indices for dataset at /home/ruihan/.cache/huggingface/datasets/gigaword/default/1.2.0/ea83a8b819190acac5f2dae011fad51dccf269a0604ec5dd24795b64efb424b6/cache-aac49639e82619d5.arrow
# max_steps is given, it will override any value given in num_train_epochs

# %%
trainer.train(resume_from_checkpoint = True)
# Out:
# The following columns in the training set don't have a corresponding argument in `LavaModel.forward` and have been ignored: input_texts, label_texts. If input_texts, label_texts are not expected by `LavaModel.forward`,  you can safely ignore this message.
# /home/ruihan/anaconda3/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 3803957
#   Num Epochs = 6
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 700000
#     <div>
#
#       <progress value='111474' max='700000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [111474/700000 7:12:20 < 38:02:33, 4.30 it/s, Epoch 0.94/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>5.293700</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>3.835900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>3.506500</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>3.437900</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>3.290300</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>3.182200</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>3.161500</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>3.111600</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>3.067200</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>3.016900</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>3.009100</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>2.976900</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>3.019900</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>3.725600</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>3.615900</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>3.066800</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>2.877000</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>2.828100</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>2.813700</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>2.800000</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>2.778100</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>2.792000</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>2.761000</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>2.750500</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>2.750100</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>2.727100</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>2.704700</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>2.725700</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>2.697600</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>2.711600</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>2.690300</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>2.700500</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>2.671800</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>2.660800</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>2.683600</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>2.654000</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>2.663500</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>2.669600</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>2.648700</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>2.639200</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>2.631800</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>2.636800</td>
#     </tr>
#     <tr>
#       <td>21500</td>
#       <td>2.625300</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>2.615400</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>2.619800</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>2.615200</td>
#     </tr>
#     <tr>
#       <td>23500</td>
#       <td>2.602700</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>2.618900</td>
#     </tr>
#     <tr>
#       <td>24500</td>
#       <td>2.611400</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>2.599900</td>
#     </tr>
#     <tr>
#       <td>25500</td>
#       <td>2.576900</td>
#     </tr>
#     <tr>
#       <td>26000</td>
#       <td>2.593800</td>
#     </tr>
#     <tr>
#       <td>26500</td>
#       <td>2.609200</td>
#     </tr>
#     <tr>
#       <td>27000</td>
#       <td>2.575800</td>
#     </tr>
#     <tr>
#       <td>27500</td>
#       <td>2.601700</td>
#     </tr>
#     <tr>
#       <td>28000</td>
#       <td>2.582600</td>
#     </tr>
#     <tr>
#       <td>28500</td>
#       <td>2.561200</td>
#     </tr>
#     <tr>
#       <td>29000</td>
#       <td>2.563600</td>
#     </tr>
#     <tr>
#       <td>29500</td>
#       <td>2.582200</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>2.570300</td>
#     </tr>
#     <tr>
#       <td>30500</td>
#       <td>2.554900</td>
#     </tr>
#     <tr>
#       <td>31000</td>
#       <td>2.565900</td>
#     </tr>
#     <tr>
#       <td>31500</td>
#       <td>2.551200</td>
#     </tr>
#     <tr>
#       <td>32000</td>
#       <td>2.578500</td>
#     </tr>
#     <tr>
#       <td>32500</td>
#       <td>2.560200</td>
#     </tr>
#     <tr>
#       <td>33000</td>
#       <td>2.545800</td>
#     </tr>
#     <tr>
#       <td>33500</td>
#       <td>2.559300</td>
#     </tr>
#     <tr>
#       <td>34000</td>
#       <td>2.537500</td>
#     </tr>
#     <tr>
#       <td>34500</td>
#       <td>2.509000</td>
#     </tr>
#     <tr>
#       <td>35000</td>
#       <td>2.533000</td>
#     </tr>
#     <tr>
#       <td>35500</td>
#       <td>2.525900</td>
#     </tr>
#     <tr>
#       <td>36000</td>
#       <td>2.526900</td>
#     </tr>
#     <tr>
#       <td>36500</td>
#       <td>2.523800</td>
#     </tr>
#     <tr>
#       <td>37000</td>
#       <td>2.508800</td>
#     </tr>
#     <tr>
#       <td>37500</td>
#       <td>2.521200</td>
#     </tr>
#     <tr>
#       <td>38000</td>
#       <td>2.533500</td>
#     </tr>
#     <tr>
#       <td>38500</td>
#       <td>2.530700</td>
#     </tr>
#     <tr>
#       <td>39000</td>
#       <td>2.516500</td>
#     </tr>
#     <tr>
#       <td>39500</td>
#       <td>2.503400</td>
#     </tr>
#     <tr>
#       <td>40000</td>
#       <td>2.507700</td>
#     </tr>
#     <tr>
#       <td>40500</td>
#       <td>2.519000</td>
#     </tr>
#     <tr>
#       <td>41000</td>
#       <td>2.525900</td>
#     </tr>
#     <tr>
#       <td>41500</td>
#       <td>2.513500</td>
#     </tr>
#     <tr>
#       <td>42000</td>
#       <td>2.505900</td>
#     </tr>
#     <tr>
#       <td>42500</td>
#       <td>2.489800</td>
#     </tr>
#     <tr>
#       <td>43000</td>
#       <td>2.504900</td>
#     </tr>
#     <tr>
#       <td>43500</td>
#       <td>2.492200</td>
#     </tr>
#     <tr>
#       <td>44000</td>
#       <td>2.500300</td>
#     </tr>
#     <tr>
#       <td>44500</td>
#       <td>2.488300</td>
#     </tr>
#     <tr>
#       <td>45000</td>
#       <td>2.498100</td>
#     </tr>
#     <tr>
#       <td>45500</td>
#       <td>2.484100</td>
#     </tr>
#     <tr>
#       <td>46000</td>
#       <td>2.497800</td>
#     </tr>
#     <tr>
#       <td>46500</td>
#       <td>2.478500</td>
#     </tr>
#     <tr>
#       <td>47000</td>
#       <td>2.487500</td>
#     </tr>
#     <tr>
#       <td>47500</td>
#       <td>2.477800</td>
#     </tr>
#     <tr>
#       <td>48000</td>
#       <td>2.490500</td>
#     </tr>
#     <tr>
#       <td>48500</td>
#       <td>2.490200</td>
#     </tr>
#     <tr>
#       <td>49000</td>
#       <td>2.491500</td>
#     </tr>
#     <tr>
#       <td>49500</td>
#       <td>2.493700</td>
#     </tr>
#     <tr>
#       <td>50000</td>
#       <td>2.478800</td>
#     </tr>
#     <tr>
#       <td>50500</td>
#       <td>2.460200</td>
#     </tr>
#     <tr>
#       <td>51000</td>
#       <td>2.480400</td>
#     </tr>
#     <tr>
#       <td>51500</td>
#       <td>2.476700</td>
#     </tr>
#     <tr>
#       <td>52000</td>
#       <td>2.472900</td>
#     </tr>
#     <tr>
#       <td>52500</td>
#       <td>2.470900</td>
#     </tr>
#     <tr>
#       <td>53000</td>
#       <td>2.449200</td>
#     </tr>
#     <tr>
#       <td>53500</td>
#       <td>2.477300</td>
#     </tr>
#     <tr>
#       <td>54000</td>
#       <td>2.473100</td>
#     </tr>
#     <tr>
#       <td>54500</td>
#       <td>2.481900</td>
#     </tr>
#     <tr>
#       <td>55000</td>
#       <td>2.455500</td>
#     </tr>
#     <tr>
#       <td>55500</td>
#       <td>2.435700</td>
#     </tr>
#     <tr>
#       <td>56000</td>
#       <td>2.468800</td>
#     </tr>
#     <tr>
#       <td>56500</td>
#       <td>2.454600</td>
#     </tr>
#     <tr>
#       <td>57000</td>
#       <td>2.450100</td>
#     </tr>
#     <tr>
#       <td>57500</td>
#       <td>2.458500</td>
#     </tr>
#     <tr>
#       <td>58000</td>
#       <td>2.432300</td>
#     </tr>
#     <tr>
#       <td>58500</td>
#       <td>2.437700</td>
#     </tr>
#     <tr>
#       <td>59000</td>
#       <td>2.447400</td>
#     </tr>
#     <tr>
#       <td>59500</td>
#       <td>2.473600</td>
#     </tr>
#     <tr>
#       <td>60000</td>
# Saving model checkpoint to lava-ce/checkpoint-5000
# Configuration saved in lava-ce/checkpoint-5000/config.json
# Model weights saved in lava-ce/checkpoint-5000/pytorch_model.bin
# Saving model checkpoint to lava-ce/checkpoint-10000
# Configuration saved in lava-ce/checkpoint-10000/config.json
# Model weights saved in lava-ce/checkpoint-10000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-200000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-15000
# Configuration saved in lava-ce/checkpoint-15000/config.json
# Model weights saved in lava-ce/checkpoint-15000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-205000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-20000
# Configuration saved in lava-ce/checkpoint-20000/config.json
# Model weights saved in lava-ce/checkpoint-20000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-5000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-25000
# Configuration saved in lava-ce/checkpoint-25000/config.json
# Model weights saved in lava-ce/checkpoint-25000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-10000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-30000
# Configuration saved in lava-ce/checkpoint-30000/config.json
# Model weights saved in lava-ce/checkpoint-30000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-15000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-35000
# Configuration saved in lava-ce/checkpoint-35000/config.json
# Model weights saved in lava-ce/checkpoint-35000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-20000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-40000
# Configuration saved in lava-ce/checkpoint-40000/config.json
# Model weights saved in lava-ce/checkpoint-40000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-25000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-45000
# Configuration saved in lava-ce/checkpoint-45000/config.json
# Model weights saved in lava-ce/checkpoint-45000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-30000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-50000
# Configuration saved in lava-ce/checkpoint-50000/config.json
# Model weights saved in lava-ce/checkpoint-50000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-35000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-55000
# Configuration saved in lava-ce/checkpoint-55000/config.json
# Model weights saved in lava-ce/checkpoint-55000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-40000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-60000
# Configuration saved in lava-ce/checkpoint-60000/config.json
# Model weights saved in lava-ce/checkpoint-60000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-45000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-65000
# Configuration saved in lava-ce/checkpoint-65000/config.json
# Model weights saved in lava-ce/checkpoint-65000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-50000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-70000
# Configuration saved in lava-ce/checkpoint-70000/config.json
# Model weights saved in lava-ce/checkpoint-70000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-55000] due to args.save_total_limit
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Saving model checkpoint to lava-ce/checkpoint-80000
# Configuration saved in lava-ce/checkpoint-80000/config.json
# Model weights saved in lava-ce/checkpoint-80000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-65000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-85000
# Configuration saved in lava-ce/checkpoint-85000/config.json
# Model weights saved in lava-ce/checkpoint-85000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-70000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-90000
# Configuration saved in lava-ce/checkpoint-90000/config.json
# Model weights saved in lava-ce/checkpoint-90000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-75000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-95000
# Configuration saved in lava-ce/checkpoint-95000/config.json
# Model weights saved in lava-ce/checkpoint-95000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-80000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-100000
# Configuration saved in lava-ce/checkpoint-100000/config.json
# Model weights saved in lava-ce/checkpoint-100000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-85000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-105000
# Configuration saved in lava-ce/checkpoint-105000/config.json
# Model weights saved in lava-ce/checkpoint-105000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-90000] due to args.save_total_limit
# Saving model checkpoint to lava-ce/checkpoint-110000
# Configuration saved in lava-ce/checkpoint-110000/config.json
# Model weights saved in lava-ce/checkpoint-110000/pytorch_model.bin
# Deleting older checkpoint [lava-ce/checkpoint-95000] due to args.save_total_limit

# %%
trainer.evaluate()
